# %% [markdown]
# # Amazon Web Scraper project

# %%
# import libraries
from bs4 import BeautifulSoup
import requests
import smtplib # To send emails to us
import time
import datetime

# %%
# Connect to website
URL = 'https://www.amazon.in/XENOVAURBAN-Oversized-Solid-T-Shirt-Blue_Size/dp/B0CVTN891G/ref=sr_1_3_sspa?crid=GSNJMIK08B6Z&dib=eyJ2IjoiMSJ9.ZFIIrIPYsH8bHlpdsJr1iADaiYXWk4CjAkmA5v1ZdnBgpVgwBc8IIjpDWkD0IKxQRZ52FE0XbrcTY3yXLND2EEDkXppBQI3RzkArVq4fX3zyuvUvGD9ngXm9MD5XnvTNSHs8d1OjidL-nkauoZRrptIYtlGR9kLnKPIGAFuSa277W49LV0uVQF1w0SP0S-icSsl1zAjx2fD4zM8K2YOm5wlAl0YelVGvNMRuRiUfJQJVVLyn5ZTgsHcXSGEVRMANL4SF7cL2t4CsdGe0KnUnrMfOF2ZZmnY3JUX1p5EuD4w.XZxTh60483oBYKHHZUGvN7MscxvoBzb813tGID7cmQM&dib_tag=se&keywords=data%2Banalyst%2Btshirt%2Bgot%2Bdata%2B%3F&qid=1783425504&sprefix=%2Caps%2C276&sr=8-3-spons&aref=qDFnvTjOWV&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1&psc=1'
headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/149.0.0.0 Safari/537.36"}
page = requests.get(URL, headers=headers)

# %%
Soup1 = BeautifulSoup(page.content, "html.parser")
Soup2 = BeautifulSoup(Soup1.prettify(), "html.parser")

title = Soup2.find(id = 'title').get_text()
price = Soup2.find(class_ = 'a-price-whole').get_text()

print(title)
print(price)
price.strip()
# Out:
#                  XENOVAURBAN Unisex Oversized Round Neck Solid T-Shirt for Men
#
#
#
#                     599
# '599'

# %%
price = price.strip()[0:]
title = title.strip()

print(title)
print(price)
# Out:
# XENOVAURBAN Unisex Oversized Round Neck Solid T-Shirt for Men
# 599

# %%
import datetime

today = datetime.date.today()
print(today)
# Out:
# 2026-09-14

# %%
# Creating a csvfile

import csv
header = ['Title', 'Price', 'Date']
data = [title, price, today]

with open('AmazonWebScraperDataset.csv', 'w', newline='', encoding='UTF8') as f: 
    writer = csv.writer(f)
    writer.writerow(header) 
    writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv(r"A:\Data analyst projects\webscraping project\AmazonWebScraperDataset.csv")
print(df)
# Out:
#                                                Title  Price        Date
# 0  XENOVAURBAN Unisex Oversized Round Neck Solid ...    599  2026-09-14

# %%
# Now we are appending data to the csv

with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f: 
    writer = csv.writer(f) 
    writer.writerow(data)

# %%
# Automating 

def check_price():
    URL = 'https://www.amazon.in/XENOVAURBAN-Oversized-Solid-T-Shirt-Blue_Size/dp/B0CVTN891G/ref=sr_1_3_sspa?crid=GSNJMIK08B6Z&dib=eyJ2IjoiMSJ9.ZFIIrIPYsH8bHlpdsJr1iADaiYXWk4CjAkmA5v1ZdnBgpVgwBc8IIjpDWkD0IKxQRZ52FE0XbrcTY3yXLND2EEDkXppBQI3RzkArVq4fX3zyuvUvGD9ngXm9MD5XnvTNSHs8d1OjidL-nkauoZRrptIYtlGR9kLnKPIGAFuSa277W49LV0uVQF1w0SP0S-icSsl1zAjx2fD4zM8K2YOm5wlAl0YelVGvNMRuRiUfJQJVVLyn5ZTgsHcXSGEVRMANL4SF7cL2t4CsdGe0KnUnrMfOF2ZZmnY3JUX1p5EuD4w.XZxTh60483oBYKHHZUGvN7MscxvoBzb813tGID7cmQM&dib_tag=se&keywords=data%2Banalyst%2Btshirt%2Bgot%2Bdata%2B%3F&qid=1783425504&sprefix=%2Caps%2C276&sr=8-3-spons&aref=qDFnvTjOWV&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1&psc=1'
    headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/149.0.0.0 Safari/537.36"}
    page = requests.get(URL, headers=headers)
    Soup1 = BeautifulSoup(page.content, "html.parser")
    Soup2 = BeautifulSoup(Soup1.prettify(), "html.parser")

    title = Soup2.find(id = 'title').get_text()
    price = Soup2.find(class_ = 'a-price-whole').get_text()

    print(title)
    print(price)
    price.strip()

    price = price.strip()[0:]
    title = title.strip()

    import datetime
    today = datetime.date.today()

    import csv
    header = ['Title', 'Price', 'Date']
    data = [title, price, today]

    with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f: 
        writer = csv.writer(f) 
        writer.writerow(data)

# %%
while(True):
    check_price()
    time.sleep(5)  # Timer set for 1 day
# Out:
#                  XENOVAURBAN Unisex Oversized Round Neck Solid T-Shirt for Men
#
#
#
#                     599
#
#
#
#                  XENOVAURBAN Unisex Oversized Round Neck Solid T-Shirt for Men
#
#
#
#                     599
#
#
#
#                  XENOVAURBAN Unisex Oversized Round Neck Solid T-Shirt for Men
#
#
#
#                     599
#
#
#
#                  XENOVAURBAN Unisex Oversized Round Neck Solid T-Shirt for Men
#
#
#
#                     599
#
#
#
#                  XENOVAURBAN Unisex Oversized Round Neck Solid T-Shirt for Men
#
#
#
#                     599
#
#
#
#                  XENOVAURBAN Unisex Oversized Round Neck Solid T-Shirt for Men
#
#
#
#                     599
#
#
#
#                  XENOVAURBAN Unisex Oversized Round Neck Solid T-Shirt for Men
#
#
#
#                     599
#
#
#
#                  XENOVAURBAN Unisex Oversized Round Neck Solid T-Shirt for Men
#
#
#
#                     599
#
#
#
#                  XENOVAURBAN Unisex Oversized Round Neck Solid T-Shirt for Men
#
#
#
#                     599
#
#
#
#                  XENOVAURBAN Unisex Oversized Round Neck Solid T-Shirt for Men
#
#
#
#                     599
#
#
#
#                  XENOVAURBAN Unisex Oversized Round Neck Solid T-Shirt for Men
#
#
#
#                     599
#
#
#
#                  XENOVAURBAN Unisex Oversized Round Neck Solid T-Shirt for Men
#
#
#
#                     599
#
#
#
#                  XENOVAURBAN Unisex Oversized Round Neck Solid T-Shirt for Men
#
#
#
#                     599
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 while(True):
# ----> 2     check_price()
#       3     time.sleep(5)  # Timer set for 1 day
#
# Cell In[9], line 6, in check_price()
#       3 def check_price():
#       4     URL = 'https://www.amazon.in/XENOVAURBAN-Oversized-Solid-T-Shirt-Blue_Size/dp/B0CVTN891G/ref=sr_1_3_sspa?crid=GSNJMIK08B6Z&dib=eyJ2IjoiMSJ9.ZFIIrIPYsH8bHlpdsJr1iADaiYXWk4CjAkmA5v1ZdnBgpVgwBc8IIjpDWkD0IKxQRZ52FE0XbrcTY3yXLND2EEDkXppBQI3RzkArVq4fX3zyuvUvGD9ngXm9MD5XnvTNSHs8d1OjidL-nkauoZRrptIYtlGR9kLnKPIGAFuSa277W49LV0uVQF1w0SP0S-icSsl1zAjx2fD4zM8K2YOm5wlAl0YelVGvNMRuRiUfJQJVVLyn5ZTgsHcXSGEVRMANL4SF7cL2t4CsdGe0KnUnrMfOF2ZZmnY3JUX1p5EuD4w.XZxTh60483oBYKHHZUGvN7MscxvoBzb813tGID7cmQM&dib_tag=se&keywords=data%2Banalyst%2Btshirt%2Bgot%2Bdata%2B%3F&qid=1783425504&sprefix=%2Caps%2C276&sr=8-3-spons&aref=qDFnvTjOWV&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1&psc=1'
#       5     headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/149.0.0.0 Safari/537.36"}
# ----> 6     page = requests.get(URL, headers=headers)
#       7     Soup1 = BeautifulSoup(page.content, "html.parser")
#       8     Soup2 = BeautifulSoup(Soup1.prettify(), "html.parser")
#       9
#
# File A:\Anaconda\Anaconda_files\Lib\site-packages\requests\api.py:87, in get(url, params, **kwargs)
#      74 def get(
#      75     url: _t.UriType, params: _t.ParamsType = None, **kwargs: Unpack[_t.GetKwargs]
#      76 ) -> Response:
#      77     r"""Sends a GET request.
#      78
#      79     :param url: URL for the new :class:`Request` object.
#    (...)     84     :rtype: requests.Response
#      85     """
# ---> 87     return request("get", url, params=params, **kwargs)
#
# File A:\Anaconda\Anaconda_files\Lib\site-packages\requests\api.py:71, in request(method, url, **kwargs)
#      67 # By using the 'with' statement we are sure the session is closed, thus we
#      68 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      69 # cases, and look like a memory leak in others.
#      70 with sessions.Session() as session:
# ---> 71     return session.request(method=method, url=url, **kwargs)
#
# File A:\Anaconda\Anaconda_files\Lib\site-packages\requests\sessions.py:651, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     646 send_kwargs = {
#     647     "timeout": timeout,
#     648     "allow_redirects": allow_redirects,
#     649 }
#     650 send_kwargs.update(settings)
# --> 651 resp = self.send(prep, **send_kwargs)
#     653 return resp
#
# File A:\Anaconda\Anaconda_files\Lib\site-packages\requests\sessions.py:827, in Session.send(self, request, **kwargs)
#     824         pass
#     826 if not stream:
# --> 827     r.content
#     829 return r
#
# File A:\Anaconda\Anaconda_files\Lib\site-packages\requests\models.py:1042, in Response.content(self)
#    1040         self._content = None
#    1041     else:
# -> 1042         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#    1044 self._content_consumed = True
#    1045 # don't need to release the connection; that's been handled by urllib3
#    1046 # since we exhausted the data.
#
# File A:\Anaconda\Anaconda_files\Lib\site-packages\requests\models.py:937, in Response.iter_content.<locals>.generate()
#     935 if hasattr(self.raw, "stream"):
#     936     try:
# --> 937         yield from self.raw.stream(chunk_size, decode_content=True)
#     938     except ProtocolError as e:
#     939         raise ChunkedEncodingError(e)
#
# File A:\Anaconda\Anaconda_files\Lib\site-packages\urllib3\response.py:1260, in HTTPResponse.stream(self, amt, decode_content)
#    1257     return
#    1259 if self.chunked and self.supports_chunked_reads():
# -> 1260     yield from self.read_chunked(amt, decode_content=decode_content)
#    1261 else:
#    1262     while (
#    1263         not is_fp_closed(self._fp)
#    1264         or len(self._decoded_buffer) > 0
#    1265         or (self._decoder and self._decoder.has_unconsumed_tail)
#    1266     ):
#
# File A:\Anaconda\Anaconda_files\Lib\site-packages\urllib3\response.py:1430, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1428     chunk = b""
#    1429 else:
# -> 1430     self._update_chunk_length()
#    1431     self._uncached_read_occurred = True
#    1432     if self.chunk_left == 0:
#
# File A:\Anaconda\Anaconda_files\Lib\site-packages\urllib3\response.py:1343, in HTTPResponse._update_chunk_length(self)
#    1341 if self.chunk_left is not None:
#    1342     return None
# -> 1343 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1344 line = line.split(b";", 1)[0]
#    1345 try:
#
# File A:\Anaconda\Anaconda_files\Lib\socket.py:729, in SocketIO.readinto(self, b)
#     727     raise OSError("cannot read from timed out object")
#     728 try:
# --> 729     return self._sock.recv_into(b)
#     730 except timeout:
#     731     self._timeout_occurred = True
#
# File A:\Anaconda\Anaconda_files\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File A:\Anaconda\Anaconda_files\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\anura\AmazonWebScraperDataset.csv")
print(df)
# Out:
#                                                 Title  Price        Date
# 0   XENOVAURBAN Unisex Oversized Round Neck Solid ...    599  2026-09-14
# 1   XENOVAURBAN Unisex Oversized Round Neck Solid ...    599  2026-09-14
# 2   XENOVAURBAN Unisex Oversized Round Neck Solid ...    599  2026-09-14
# 3   XENOVAURBAN Unisex Oversized Round Neck Solid ...    599  2026-09-14
# 4   XENOVAURBAN Unisex Oversized Round Neck Solid ...    599  2026-09-14
# 5   XENOVAURBAN Unisex Oversized Round Neck Solid ...    599  2026-09-14
# 6   XENOVAURBAN Unisex Oversized Round Neck Solid ...    599  2026-09-14
# 7   XENOVAURBAN Unisex Oversized Round Neck Solid ...    599  2026-09-14
# 8   XENOVAURBAN Unisex Oversized Round Neck Solid ...    599  2026-09-14
# 9   XENOVAURBAN Unisex Oversized Round Neck Solid ...    599  2026-09-14
# 10  XENOVAURBAN Unisex Oversized Round Neck Solid ...    599  2026-09-14
# 11  XENOVAURBAN Unisex Oversized Round Neck Solid ...    599  2026-09-14
# 12  XENOVAURBAN Unisex Oversized Round Neck Solid ...    599  2026-09-14
# 13  XENOVAURBAN Unisex Oversized Round Neck Solid ...    599  2026-09-14
# 14  XENOVAURBAN Unisex Oversized Round Neck Solid ...    599  2026-09-14

# %%
import smtplib

def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
    
    email = 'your gmail'
    app_password = 'password'
    
    server.login(email, app_password)

    subject = "The shirt you want is below Rs.200. Now is your chance to buy it!"
    body = "Anurag, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dream. Don't miss the opportunity."

    msg = f"Subject: {subject}\n\n{body}"

    server.sendmail(
        email,              # Sender
        email,              # Receiver
        msg                 # Message
    )

    server.quit()

send_mail()
print("Mail sent successfully!")
# Out:
# Mail sent successfully!
